# %% [markdown]
# # Random Forest Classifier & Decision Tree Classifier
# ###### Created by Esmira Abdullaieva & Shovak Myroslav

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# ### Dataset analysis

# %%
df = pd.read_csv('Mobile_Price.csv')

# %%
print('The number of duplicates:', df.duplicated().sum())
print(f'Empty cells:\n{df.isnull().sum()}')
# Out:
# The number of duplicates: 0
# Empty cells:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# #### Correlation analysis

# %%
correlation = df.corr()
correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7d516_row0_col0, #T_7d516_row1_col1, #T_7d516_row2_col2, #T_7d516_row3_col3, #T_7d516_row4_col4, #T_7d516_row5_col5, #T_7d516_row6_col6, #T_7d516_row7_col7, #T_7d516_row8_col8, #T_7d516_row9_col9, #T_7d516_row10_col10, #T_7d516_row11_col11, #T_7d516_row12_col12, #T_7d516_row13_col13, #T_7d516_row14_col14, #T_7d516_row15_col15, #T_7d516_row16_col16, #T_7d516_row17_col17, #T_7d516_row18_col18, #T_7d516_row19_col19, #T_7d516_row20_col20 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col2, #T_7d516_row6_col1, #T_7d516_row13_col15, #T_7d516_row15_col1, #T_7d516_row20_col15 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col3, #T_7d516_row0_col14, #T_7d516_row0_col15, #T_7d516_row3_col10, #T_7d516_row5_col13, #T_7d516_row6_col19, #T_7d516_row7_col11, #T_7d516_row7_col14, #T_7d516_row12_col2, #T_7d516_row15_col10, #T_7d516_row15_col16, #T_7d516_row16_col10, #T_7d516_row17_col11, #T_7d516_row18_col14, #T_7d516_row19_col16 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col4, #T_7d516_row1_col0, #T_7d516_row1_col2, #T_7d516_row1_col4, #T_7d516_row2_col0, #T_7d516_row3_col13, #T_7d516_row5_col14, #T_7d516_row8_col2, #T_7d516_row10_col0, #T_7d516_row14_col6, #T_7d516_row15_col13, #T_7d516_row16_col20, #T_7d516_row20_col1, #T_7d516_row20_col3, #T_7d516_row20_col16 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col5, #T_7d516_row8_col17, #T_7d516_row13_col3, #T_7d516_row13_col17, #T_7d516_row17_col20 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col6, #T_7d516_row3_col4, #T_7d516_row3_col14, #T_7d516_row5_col9, #T_7d516_row6_col4, #T_7d516_row6_col8, #T_7d516_row7_col13, #T_7d516_row8_col4, #T_7d516_row9_col6, #T_7d516_row10_col18, #T_7d516_row11_col2, #T_7d516_row11_col3, #T_7d516_row12_col1, #T_7d516_row12_col4, #T_7d516_row12_col13, #T_7d516_row15_col4, #T_7d516_row17_col2, #T_7d516_row17_col19, #T_7d516_row18_col11, #T_7d516_row20_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col7, #T_7d516_row0_col10, #T_7d516_row4_col0, #T_7d516_row5_col18, #T_7d516_row6_col12, #T_7d516_row7_col1, #T_7d516_row10_col8, #T_7d516_row12_col14, #T_7d516_row14_col20, #T_7d516_row15_col11, #T_7d516_row18_col16, #T_7d516_row20_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col8, #T_7d516_row1_col16, #T_7d516_row3_col19, #T_7d516_row5_col6, #T_7d516_row5_col20, #T_7d516_row6_col16, #T_7d516_row7_col0, #T_7d516_row7_col8, #T_7d516_row9_col15, #T_7d516_row9_col17, #T_7d516_row14_col1, #T_7d516_row15_col19, #T_7d516_row17_col13, #T_7d516_row19_col4, #T_7d516_row19_col15, #T_7d516_row19_col17, #T_7d516_row20_col5, #T_7d516_row20_col7, #T_7d516_row20_col19 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col9, #T_7d516_row2_col13, #T_7d516_row3_col5, #T_7d516_row4_col12, #T_7d516_row4_col15, #T_7d516_row6_col10, #T_7d516_row7_col19, #T_7d516_row8_col12, #T_7d516_row8_col15, #T_7d516_row10_col6, #T_7d516_row14_col3, #T_7d516_row14_col10, #T_7d516_row14_col19, #T_7d516_row18_col8, #T_7d516_row18_col20 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col11, #T_7d516_row1_col3, #T_7d516_row1_col6, #T_7d516_row2_col16, #T_7d516_row2_col17, #T_7d516_row6_col9, #T_7d516_row6_col13, #T_7d516_row6_col15, #T_7d516_row7_col12, #T_7d516_row8_col7, #T_7d516_row9_col12, #T_7d516_row10_col19, #T_7d516_row11_col9, #T_7d516_row13_col6, #T_7d516_row13_col19, #T_7d516_row16_col13, #T_7d516_row18_col4, #T_7d516_row18_col12, #T_7d516_row19_col5, #T_7d516_row20_col10 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col12, #T_7d516_row1_col11, #T_7d516_row2_col6, #T_7d516_row2_col10, #T_7d516_row3_col7, #T_7d516_row5_col7, #T_7d516_row7_col3, #T_7d516_row7_col4, #T_7d516_row7_col10, #T_7d516_row8_col16, #T_7d516_row10_col13, #T_7d516_row12_col18, #T_7d516_row13_col5, #T_7d516_row13_col10, #T_7d516_row14_col2, #T_7d516_row16_col2, #T_7d516_row16_col7, #T_7d516_row16_col17, #T_7d516_row17_col10, #T_7d516_row17_col18, #T_7d516_row18_col3, #T_7d516_row18_col7, #T_7d516_row19_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col13, #T_7d516_row2_col9, #T_7d516_row2_col15, #T_7d516_row3_col12, #T_7d516_row3_col18, #T_7d516_row4_col13, #T_7d516_row5_col10, #T_7d516_row7_col18, #T_7d516_row9_col2, #T_7d516_row9_col3, #T_7d516_row10_col12, #T_7d516_row10_col15, #T_7d516_row11_col5, #T_7d516_row12_col8, #T_7d516_row13_col8, #T_7d516_row15_col18, #T_7d516_row16_col6, #T_7d516_row18_col6, #T_7d516_row18_col15, #T_7d516_row19_col7, #T_7d516_row19_col14 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col16, #T_7d516_row20_col17 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col17, #T_7d516_row2_col8, #T_7d516_row3_col20, #T_7d516_row10_col1, #T_7d516_row10_col17, #T_7d516_row11_col1, #T_7d516_row15_col12, #T_7d516_row17_col14, #T_7d516_row18_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col18, #T_7d516_row2_col12, #T_7d516_row3_col6, #T_7d516_row4_col16, #T_7d516_row5_col3, #T_7d516_row12_col10, #T_7d516_row14_col7, #T_7d516_row15_col0, #T_7d516_row15_col3, #T_7d516_row17_col3, #T_7d516_row18_col10, #T_7d516_row19_col9 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col19, #T_7d516_row1_col5, #T_7d516_row1_col7, #T_7d516_row1_col10, #T_7d516_row2_col14, #T_7d516_row4_col19, #T_7d516_row6_col17, #T_7d516_row7_col5, #T_7d516_row7_col16, #T_7d516_row7_col17, #T_7d516_row8_col3, #T_7d516_row9_col8, #T_7d516_row9_col14, #T_7d516_row10_col14, #T_7d516_row10_col16, #T_7d516_row12_col16, #T_7d516_row13_col7, #T_7d516_row13_col12, #T_7d516_row14_col9, #T_7d516_row16_col8, #T_7d516_row17_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_7d516_row0_col20 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_7d516_row1_col8, #T_7d516_row4_col11, #T_7d516_row4_col14, #T_7d516_row8_col11, #T_7d516_row9_col0, #T_7d516_row13_col18, #T_7d516_row14_col4, #T_7d516_row15_col7, #T_7d516_row16_col4, #T_7d516_row18_col0, #T_7d516_row19_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_7d516_row1_col9, #T_7d516_row3_col8, #T_7d516_row12_col6, #T_7d516_row12_col7, #T_7d516_row12_col9, #T_7d516_row13_col4, #T_7d516_row16_col18, #T_7d516_row17_col0, #T_7d516_row18_col9, #T_7d516_row19_col8, #T_7d516_row20_col9 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_7d516_row1_col12, #T_7d516_row1_col17, #T_7d516_row2_col7, #T_7d516_row2_col19, #T_7d516_row4_col9, #T_7d516_row5_col11, #T_7d516_row5_col16, #T_7d516_row7_col2, #T_7d516_row7_col15, #T_7d516_row8_col6, #T_7d516_row8_col13, #T_7d516_row8_col14, #T_7d516_row8_col18, #T_7d516_row8_col20, #T_7d516_row9_col4, #T_7d516_row9_col10, #T_7d516_row9_col19, #T_7d516_row10_col11, #T_7d516_row11_col10, #T_7d516_row11_col13, #T_7d516_row13_col11, #T_7d516_row14_col0, #T_7d516_row14_col16, #T_7d516_row14_col18, #T_7d516_row16_col3, #T_7d516_row16_col5, #T_7d516_row16_col14, #T_7d516_row16_col15, #T_7d516_row16_col19, #T_7d516_row17_col1, #T_7d516_row17_col6, #T_7d516_row18_col13, #T_7d516_row20_col8, #T_7d516_row20_col18 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7d516_row1_col13, #T_7d516_row1_col14, #T_7d516_row1_col18, #T_7d516_row2_col5, #T_7d516_row4_col5, #T_7d516_row4_col7, #T_7d516_row4_col18, #T_7d516_row5_col8, #T_7d516_row6_col18, #T_7d516_row8_col0, #T_7d516_row8_col5, #T_7d516_row8_col9, #T_7d516_row8_col10, #T_7d516_row9_col13, #T_7d516_row9_col16, #T_7d516_row9_col18, #T_7d516_row10_col3, #T_7d516_row11_col7, #T_7d516_row11_col8, #T_7d516_row11_col18, #T_7d516_row13_col0, #T_7d516_row13_col2, #T_7d516_row15_col2, #T_7d516_row15_col6, #T_7d516_row16_col12, #T_7d516_row17_col9, #T_7d516_row19_col1, #T_7d516_row19_col10, #T_7d516_row19_col13 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_7d516_row1_col15, #T_7d516_row2_col4, #T_7d516_row4_col2, #T_7d516_row5_col1, #T_7d516_row9_col20, #T

# %%
# removing weakly correlated data
df = df.drop(['clock_speed', 'mobile_wt', 'touch_screen'], axis=1)

# %%
y = df['price_range']
X = df.drop(['price_range'], axis=1)

# %%
# separation of data into test and training
SEED = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=SEED)

# %% [markdown]
# ### Random Forest Classifier

# %%
# creating Random Forest Classifier model and it's initialization
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
accuracy = rfc.score(X_test, y_test)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.8171641791044776

# %%
price_predict = rfc.predict(X_test)
print(f'Predict price:\n{price_predict}')
# Out:
# Predict price:
# [1 3 3 3 0 3 2 3 2 0 3 3 3 1 2 3 3 2 1 3 0 1 2 1 1 1 0 0 2 2 0 1 0 0 3 2 0
#  3 0 2 0 3 2 1 2 3 0 0 1 2 3 2 1 2 1 1 2 3 0 2 0 0 3 0 1 0 3 2 3 2 3 1 0 3
#  0 3 2 0 1 3 0 3 0 3 0 3 1 3 0 2 3 1 0 0 2 2 3 2 2 3 3 0 0 1 0 0 3 1 3 2 1
#  1 3 0 0 2 3 0 1 1 0 2 0 2 1 0 3 1 1 2 3 0 0 0 3 3 0 2 3 3 1 1 3 3 2 2 0 3
#  1 2 0 3 1 3 1 1 0 2 3 2 2 3 1 2 2 1 3 0 2 3 3 1 1 1 1 3 3 3 3 1 2 0 3 0 3
#  3 3 3 1 3 3 1 0 3 3 2 0 2 0 0 3 0 3 1 1 2 1 2 3 1 3 2 0 0 2 0 0 1 0 2 1 1
#  1 3 2 3 2 3 2 2 2 0 0 0 3 2 1 3 1 3 2 2 0 3 1 3 3 0 3 2 3 3 3 1 1 2 1 1 0
#  2 2 0 1 0 1 2 3 0 1 2 1 1 3 0 3 1 1 3 2 0 3 1 3 1 0 2 0 3 1 0 3 0 3 1 2 0
#  3 0 3 0 3 1 0 0 0 3 1 2 3 1 0 0 2 2 1 3 3 3 2 1 2 3 0 1 1 3 1 0 3 0 1 0 0
#  1 3 2 0 1 2 3 2 0 0 0 3 3 2 2 0 3 1 3 1 0 3 2 3 1 1 0 1 1 3 2 1 3 1 0 0 2
#  3 0 1 2 1 3 1 1 2 3 3 2 0 2 3 0 0 1 1 0 0 2 1 1 1 0 1 3 2 0 0 0 3 1 3 1 3
#  1 0 0 2 3 1 0 1 1 3 0 0 2 2 3 1 2 2 2 2 0 1 3 3 3 0 3 0 2 0 0 2 1 3 1 2 0
#  0 2 2 3 3 0 2 0 3 1 0 2 3 3 0 0 3 3 1 3 2 3 0 3 1 3 2 3 1 2 2 1 3 3 3 1 3
#  1 0 1 2 3 1 0 0 1 3 0 3 1 3 1 2 0 0 2 2 0 3 1 2 0 3 1 3 0 0 3 3 3 0 2 2 2
#  0 2 2 0 3 3 3 1 2 0 3 0 1 3 3 0 3 1]

# %%
# comparing results with actual data
pd.DataFrame({'Actual': y_test, 'Predicted': price_predict})
# Out:
#       Actual  Predicted
# 992        1          1
# 746        3          3
# 1066       3          3
# 425        2          3
# 490        0          0
# ...      ...        ...
# 720        3          3
# 940        3          3
# 61         0          0
# 272        3          3
# 991        1          1
#
# [536 rows x 2 columns]

# %%
# calculating of metrix
mae = mean_absolute_error(y_test, price_predict)
mse = mean_squared_error(y_test, price_predict)
rmse = mean_squared_error(y_test, price_predict, squared = False)
relative_error = round(rmse/price_predict.mean()*100, 2)

print(f'{mse = }\n{rmse = }\n{relative_error = }%\n')
# Out:
# mse = 0.0914179104477612
# rmse = 0.30235394895347606
# relative_error = 19.44%

# %% [markdown]
# ### Decision Tree Classifier

# %%
dfc = DecisionTreeClassifier()
dfc.fit(X_train, y_train)
accuracy = dfc.score(X_test, y_test)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.8041044776119403

# %%
price_predict = dfc.predict(X_test)
print(f'Predict price:\n{price_predict}')
# Out:
# Predict price:
# [1 3 3 3 0 3 2 3 2 0 3 3 3 1 2 3 3 2 2 3 0 1 2 1 0 2 1 1 2 2 0 1 0 1 3 2 0
#  3 0 1 0 3 1 1 2 3 0 0 2 2 2 1 0 2 0 2 2 3 0 3 0 1 2 0 1 0 2 1 2 2 3 1 1 3
#  0 3 2 0 1 3 0 3 1 3 0 3 1 3 0 2 3 1 0 0 2 2 3 2 2 3 3 1 0 1 0 0 3 1 3 1 1
#  1 3 0 0 2 3 0 1 1 0 1 0 2 0 1 2 1 2 3 2 1 0 0 3 3 0 2 3 3 1 1 3 3 1 2 0 3
#  1 2 1 2 1 3 2 2 0 2 3 2 2 3 1 2 2 1 3 0 2 3 3 1 1 1 1 3 3 3 3 1 2 0 3 0 3
#  3 3 3 1 3 3 1 0 3 3 2 1 2 0 0 2 0 3 1 1 1 1 2 3 1 3 2 0 1 2 0 1 1 0 2 2 1
#  1 3 2 2 2 2 2 2 2 0 0 1 3 2 1 3 2 3 2 2 0 3 1 3 3 0 3 2 3 3 2 1 1 2 1 1 1
#  2 2 0 1 0 1 2 3 0 1 3 1 2 3 0 3 1 1 3 3 0 3 1 3 1 0 2 0 3 1 0 2 0 3 1 1 0
#  3 0 3 0 3 0 0 0 0 2 1 2 2 1 0 0 2 2 1 3 3 3 2 1 1 3 0 2 1 3 1 0 2 0 1 1 0
#  1 3 2 0 2 2 3 2 0 0 0 3 2 2 2 0 3 1 3 0 0 3 2 3 0 1 0 1 2 3 2 1 2 1 0 0 2
#  3 0 1 2 1 2 1 1 2 3 3 1 0 2 3 0 1 1 2 0 0 2 1 1 2 0 1 3 1 0 0 0 3 1 3 1 3
#  1 0 0 2 3 1 0 1 1 3 0 0 2 3 3 1 2 1 2 2 1 1 3 3 3 0 3 0 2 0 1 2 0 3 1 2 0
#  0 2 2 3 3 0 2 0 3 1 0 2 3 3 0 0 3 3 1 3 2 3 0 3 1 3 2 2 1 1 3 1 3 3 3 1 3
#  1 1 2 2 3 1 1 0 1 3 0 3 1 3 1 2 0 0 2 2 0 3 1 2 0 3 1 2 0 0 3 3 3 0 1 2 2
#  0 2 2 0 2 3 3 1 2 0 3 0 1 2 3 0 2 1]

# %%
# comparing results with actual data
pd.DataFrame({'Actual': y_test, 'Predicted': price_predict})
# Out:
#       Actual  Predicted
# 992        1          1
# 746        3          3
# 1066       3          3
# 425        2          3
# 490        0          0
# ...      ...        ...
# 720        3          2
# 940        3          3
# 61         0          0
# 272        3          2
# 991        1          1
#
# [536 rows x 2 columns]

# %%
# calculating of metrix
mae = mean_absolute_error(y_test, price_predict)
mse = mean_squared_error(y_test, price_predict)
rmse = mean_squared_error(y_test, price_predict, squared=False)
relative_error = round(rmse/price_predict.mean()*100, 2)

print(f'{mse = }\n{rmse = }\n{relative_error = }%\n')
# Out:
# mse = 0.10354477611940298
# rmse = 0.32178374122911024
# relative_error = 20.73%
